# %% [markdown]
# ## IMPORTS

# %%
import os
from datetime import datetime

# Matrices
import numpy as np

# DF
import pandas as pd
import papermill as pm

base_path = "/home/jovyan/work/TP3_TP4"  # other /home/jovyan/work/TP3_TP4
os.chdir(base_path)

# %%
# START TIME ------
s = datetime.now()
# time as str
init_time = s.strftime("%d-%m-%Y_%H:%M:%S")
print(f"Starting time and time used for files {init_time}")
pd.set_option("display.float_format", lambda x: "%.5f" % x)
# Out:
# Starting time and time used for files 06-02-2022_13:56:51

# %% [markdown]
# ## SET UP EXECUTIONER

# %% [markdown]
# **Defaults:**
# - categorical =True :
#     * implies: Categorical columns are dummified by sklearn encoder
# - toFitXGB= True
# - toFitRF= True
# - toFitSVM= True
# - toFitMLP= True
# - toScale= True
#     * Numerical columns are scaled by mean and std

# %% [markdown]
# ### Execute all models on house data

# %%
# HOUSE DATA FITTING ------
pm.execute_notebook(
    "/home/jovyan/work/TP3_TP4/trainers/house_trainer.ipynb",
    "/home/jovyan/work/TP3_TP4/Jupyter Outputs/house_trained.ipynb",
    parameters=dict(
        training_data_path="house_train",
        dataset="house",
        dependent="SalePrice",
        toFitXGB=True,
        toFitMLP=False,
    ),
);
# Out:
# Executing:   0%|          | 0/65 [00:00<?, ?cell/s]
# /opt/conda/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/conda/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/conda/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# ...

# %%
# HOUSE DATA FITTING ------
pm.execute_notebook(
    "/home/jovyan/work/CM_ML/TP3_TP4/trainers/house_trainer.ipynb",
    "/home/jovyan/work/CM_ML/TP3_TP4/Jupyter Outputs/house_trained.ipynb",
    parameters=dict(
        toScale=False,
        training_data_path="house_train",
        dataset="house",
        dependent="SalePrice",
    ),
);

# %%
# BILL DATA FITTING ------

pm.execute_notebook(
    "/home/jovyan/work/TP3_TP4/trainers/house_trainer.ipynb",
    "/home/jovyan/work/TP3_TP4/Jupyter Outputs/bill_trained.ipynb",
    parameters=dict(
        to_rm_storage=False,
        training_data_path="bill_train",
        dataset="bill",
        dependent="Class",
    ),
)
# storage is not removed

# %%
# WINE DATA FITTING ------
pm.execute_notebook(
    "/home/jovyan/work/TP3_TP4/trainers/cat_trainer.ipynb",
    "/home/jovyan/work/TP3_TP4/Jupyter Outputs/bill_trained.ipynb",
    parameters=dict(
        to_rm_storage=False,
        training_data_path="bill_train",
        dataset="bill",
        dependent="Class",
        categorical=False,
    ),
)
# storage is not removed
# Out:
# Executing:   0%|          | 0/66 [00:00<?, ?cell/s]
# /opt/conda/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/conda/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/conda/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# ...
